# %% [markdown]
# ## Intallations

# %%
# !pip install openai pillow numpy opencv-python jiwer matplotlib pandas requests
# Out:
# Requirement already satisfied: openai in /mnt/silenos/silenos1/nlp/projekty/mtlowre/lmo_ocr/qwen_env/lib/python3.10/site-packages (2.45.0)
# Requirement already satisfied: pillow in /mnt/silenos/silenos1/nlp/projekty/mtlowre/lmo_ocr/qwen_env/lib/python3.10/site-packages (12.3.0)
# Requirement already satisfied: numpy in /mnt/silenos/silenos1/nlp/projekty/mtlowre/lmo_ocr/qwen_env/lib/python3.10/site-packages (2.2.6)
# Requirement already satisfied: opencv-python in /mnt/silenos/silenos1/nlp/projekty/mtlowre/lmo_ocr/qwen_env/lib/python3.10/site-packages (5.0.0.93)
# Requirement already satisfied: jiwer in /mnt/silenos/silenos1/nlp/projekty/mtlowre/lmo_ocr/qwen_env/lib/python3.10/site-packages (4.0.0)
# Requirement already satisfied: matplotlib in /mnt/silenos/silenos1/nlp/projekty/mtlowre/lmo_ocr/qwen_env/lib/python3.10/site-packages (3.10.9)
# Requirement already satisfied: pandas in /mnt/silenos/silenos1/nlp/projekty/mtlowre/lmo_ocr/qwen_env/lib/python3.10/site-packages (2.3.3)
# Requirement already satisfied: requests in /mnt/silenos/silenos1/nlp/projekty/mtlowre/lmo_ocr/qwen_env/lib/python3.10/site-packages (2.34.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /mnt/silenos/silenos1/nlp/projekty/mtlowre/lmo_ocr/qwen_env/lib/python3.10/site-packages (from openai) (4.14.2)
# Requirement already satisfied: distro<2,>=1.7.0 in /mnt/silenos/silenos1/nlp/projekty/mtlowre/lmo_ocr/qwen_env/lib/python3.10/site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /mnt/silenos/silenos1/nlp/projekty/mtlowre/lmo_ocr/qwen_env/lib/python3.10/site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in /mnt/silenos/silenos1/nlp/projekty/mtlowre/lmo_ocr/qwen_env/lib/python3.10/site-packages (from openai) (0.16.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /mnt/silenos/silenos1/nlp/projekty/mtlowre/lmo_ocr/qwen_env/lib/python3.10/site-packages (from openai) (2.13.4)
# Requirement already satisfied: sniffio in /mnt/silenos/silenos1/nlp/projekty/mtlowre/lmo_ocr/qwen_env/lib/python3.10/site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /mnt/silenos/silenos1/nlp/projekty/mtlowre/lmo_ocr/qwen_env/lib/python3.10/site-packages (from openai) (4.68.4)
# Requirement already satisfied: typing-extensions<5,>=4.14 in /mnt/silenos/silenos1/nlp/projekty/mtlowre/lmo_ocr/qwen_env/lib/python3.10/site-packages (from openai) (4.16.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /mnt/silenos/silenos1/nlp/projekty/mtlowre/lmo_ocr/qwen_env/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /mnt/silenos/silenos1/nlp/projekty/mtlowre/lmo_ocr/qwen_env/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai) (3.18)
# Requirement already satisfied: certifi in /mnt/silenos/silenos1/nlp/projekty/mtlowre/lmo_ocr/qwen_env/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in /mnt/silenos/silenos1/nlp/projekty/mtlowre/lmo_ocr/qwen_env/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /mnt/silenos/silenos1/nlp/projekty/mtlowre/lmo_ocr/qwen_env/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /mnt/silenos/silenos1/nlp/projekty/mtlowre/lmo_ocr/qwen_env/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /mnt/silenos/silenos1/nlp/projekty/mtlowre/lmo_ocr/qwen_env/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->openai) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /mnt/silenos/silenos1/nlp/projekty/mtlowre/lmo_ocr/qwen_env/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)
# Requirement already satisfied: click>=8.1.8 in /mnt/silenos/silenos1/nlp/projekty/mtlowre/lmo_ocr/qwen_env/lib/python3.10/site-packages (from jiwer) (8.4.2)
# Requirement already satisfied: rapidfuzz>=3.9.7 in /mnt/silenos/silenos1/nlp/projekty/mtlowre/lmo_ocr/qwen_env/lib/python3.10/site-packages (from jiwer) (3.14.5)
# Requirement already satisfied: contourpy>=1.0.1 in /mnt/silenos/silenos1/nlp/projekty/mtlowre/lmo_ocr/qwen_env/lib/python3.10/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /mnt/silenos/silenos1/nlp/projekty/mtlowre/lmo_ocr/qwen_env/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /mnt/silenos/silenos1/nlp/projekty/mtlowre/lmo_ocr/qwen_env/lib/python3.10/site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /mnt/silenos/silenos1/nlp/projekty/mtlowre/lmo_ocr/qwen_env/lib/python3.10/site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /mnt/silenos/silenos1/nlp/projekty/mtlowre/lmo_ocr/qwen_env/lib/python3.10/site-packages (from matplotlib) (26.2)
# Requirement already satisfied: pyparsing>=3 in /mnt/silenos/silenos1/nlp/projekty/mtlowre/lmo_ocr/qwen_env/lib/python3.10/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /mnt/silenos/silenos1/nlp/projekty/mtlowre/lmo_ocr/qwen_env/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /mnt/silenos/silenos1/nlp/projekty/mtlowre/lmo_ocr/qwen_env/lib/python3.10/site-packages (from pandas) (2026.2)
# Requirement already satisfied: tzdata>=2022.7 in /mnt/silenos/silenos1/nlp/projekty/mtlowre/lmo_ocr/qwen_env/lib/python3.10/site-packages (from pandas) (2026.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /mnt/silenos/silenos1/nlp/projekty/mtlowre/lmo_ocr/qwen_env/lib/python3.10/site-packages (from requests) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.26 in /mnt/silenos/silenos1/nlp/projekty/mtlowre/lmo_ocr/qwen_env/lib/python3.10/site-packages (from requests) (2.7.0)
# Requirement already satisfied: six>=1.5 in /mnt/silenos/silenos1/nlp/projekty/mtlowre/lmo_ocr/qwen_env/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
# !vllm --version
# Out:
# 0.25.0+cu129

# %%
from openai import OpenAI

VLLM_BASE_URL = "http://127.0.0.1:8000/v1"
MODEL_NAME = "Qwen/Qwen3.5-35B-A3B-GPTQ-Int4"

client = OpenAI(
    base_url=VLLM_BASE_URL,
    api_key="EMPTY"
)

models = client.models.list()

for model in models.data:
    print(model.id)
# Out:
# Qwen/Qwen3.5-35B-A3B-GPTQ-Int4

# %%
try:
    models = client.models.list()

    print("Connected to the local vLLM server.")
    print("Available models:")

    for model in models.data:
        print("-", model.id)

except Exception as e:
    print("Could not connect to the vLLM server.")
    print("Make sure vLLM is running on port 8000.")
    print("Error:", e)
# Out:
# Connected to the local vLLM server.
# Available models:
# - Qwen/Qwen3.5-35B-A3B-GPTQ-Int4

# %%
import sys
import torch


print("Torch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
    print("Torch CUDA:", torch.version.cuda)
# Out:
# Torch version: 2.11.0+cu129
# CUDA available: True
# GPU: NVIDIA A100 80GB PCIe
# Torch CUDA: 12.9

# %%
import torch
from PIL import Image
import matplotlib.pyplot as plt
import requests
import pandas as pd
import re
from jiwer import wer, cer

# %% [markdown]
# ### Image Download

# %%
import os
import platform

pages = [8, 9, 38]

base = "https://nlp.fi.muni.cz/projekty/ahisto/book_by_id/494/"

os.makedirs("images", exist_ok=True)
os_type = platform.system()
print("OS: ", os_type)

for p in pages:
    path = f"images/{p}.jpg"
    
    if not os.path.exists(path):
        if os_type == "Windows":
            # !curl -o {path} {base}{p}.jpg
            # !curl -k -L -o {path} {base}{p}.jpg # ignore certificate verification, follow redirects
        else:
            # !wget -O {path} {base}{p}.jpg
    else:
        print(f"Already exists: {path}")
# Out:
# OS:  Linux
# --2026-07-13 15:20:38--  https://nlp.fi.muni.cz/projekty/ahisto/book_by_id/494/8.jpg
# Resolving nlp.fi.muni.cz (nlp.fi.muni.cz)... 147.251.51.11
# Connecting to nlp.fi.muni.cz (nlp.fi.muni.cz)|147.251.51.11|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 368596 (360K) [image/jpeg]
# Saving to: ‘images/8.jpg’
#
# images/8.jpg        100%[===================>] 359.96K  --.-KB/s    in 0.06s
#
# 2026-07-13 15:20:38 (6.35 MB/s) - ‘images/8.jpg’ saved [368596/368596]
#
# --2026-07-13 15:20:39--  https://nlp.fi.muni.cz/projekty/ahisto/book_by_id/494/9.jpg
# Resolving nlp.fi.muni.cz (nlp.fi.muni.cz)... 147.251.51.11
# Connecting to nlp.fi.muni.cz (nlp.fi.muni.cz)|147.251.51.11|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 496474 (485K) [image/jpeg]
# Saving to: ‘images/9.jpg’
#
# images/9.jpg        100%[===================>] 484.84K  --.-KB/s    in 0.1s
#
# 2026-07-13 15:20:39 (4.58 MB/s) - ‘images/9.jpg’ saved [496474/496474]
#
# --2026-07-13 15:20:39--  https://nlp.fi.muni.cz/projekty/ahisto/book_by_id/494/38.jpg
# Resolving nlp.fi.muni.cz (nlp.fi.muni.cz)... 147.251.51.11
# Connecting to nlp.fi.muni.cz (nlp.fi.muni.cz)|147.251.51.11|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 425617 (416K) [image/jpeg]
# Saving to: ‘images/38.jpg’
#
# images/38.jpg       100%[===================>] 415.64K  --.-KB/s    in 0.05s
#
# 2026-07-13 15:20:39 (8.88 MB/s) - ‘images/38.jpg’ saved [425617/425617]

# %% [markdown]
# ## Prompt Design

# %%
# bad prompt design - page 8 wer 5.2% cer 0.8%
prompt_text_1 = "Extract all text from this image exactly as written. Preserve line breaks."

# %%
# best prompt result =  page 8 WER 1.9%  cer 0.3% 
prompt_text_2 = """
You are an OCR specialist.

Extract every visible character from this image exactly as it appears.

Return plain text only. Preserve the original reading order, line breaks, paragraph breaks, headings, punctuation, capitalization, spelling, abbreviations, umlauts, ß, Roman numerals, page numbers, and hyphenation exactly as printed.

Do not correct spelling or grammar. Do not modernize, normalize, translate, summarize, explain, or infer missing text. Do not merge words that are split by line-ending hyphens.

If any character or word cannot be read with confidence, write [illegible] exactly at that position instead of guessing.

Do not include any comments, Markdown, labels, or additional text. Return only the transcription.
"""

# %%
# bad prompt design too much contents - page 8 wer 6.2% cer 0.9%
prompt_text_3 = """
Transcribe this historical German printed page as accurately and literally as possible.

Return plain text only.

This page may contain:
- a running header and page number,
- numbered document entries,
- source descriptions,
- historical German text,
- marginal line numbers,
- marginal dates or reference notes,
- superscript footnote markers,
- and footnotes printed in columns at the bottom.

Use the following transcription order:

1. Transcribe the running header and page number.
2. Transcribe the main page content from top to bottom and left to right.
3. Keep each numbered document entry in its correct sequence.
4. Transcribe footnotes after the main text, reading the left footnote column before the right footnote column.
5. Transcribe marginal annotations separately after the related main text. Do not insert marginal dates, line numbers, or reference labels into the middle of a sentence.

Preserve exactly what is visibly printed, including:
- historical and archaic spelling,
- capitalization,
- punctuation,
- abbreviations,
- umlauts,
- ß,
- Roman numerals,
- square brackets,
- parentheses,
- superscript footnote markers,
- page and volume markers,
- and words divided by hyphens at line endings.

Do not modernize spelling.
Do not correct grammar.
Do not replace archaic words with modern German.
Do not complete partially visible words from context.
Do not translate, summarize, explain, or interpret the text.
Do not add Markdown, headings, comments, labels, or quotation marks that are not printed.
Do not duplicate marginal text.
Do not merge separate text regions into one sentence.

When a character is uncertain, choose the character that is best supported by its visible shape rather than by linguistic probability. Use [illegible] only when no character can be determined visually.

Return only the transcription.
"""

# %%
import base64
import mimetypes


def run_ocr_one_image(image_path, prompt_text):
    """
    Sending one image to Qwen3.5 through the local vLLM server
    """

    mime_type, _ = mimetypes.guess_type(image_path)

    if mime_type is None:
        mime_type = "image/jpeg"

    with open(image_path, "rb") as image_file:
        image_base64 = base64.b64encode(
            image_file.read()
        ).decode("utf-8")

    image_data_url = (
        f"data:{mime_type};base64,{image_base64}"
    )

    response = client.chat.completions.create(
        model=MODEL_NAME,
        messages=[
            {
                "role": "user",
                "content": [
                    {
                        "type": "image_url",
                        "image_url": {
                            "url": image_data_url
                        }
                    },
                    {
                        "type": "text",
                        "text": prompt_text
                    }
                ]
            }
        ],
        temperature=0.0,
        max_tokens=2000,
        extra_body={
            "chat_template_kwargs": {
                "enable_thinking": False
            }
        }
    )

    output_text = response.choices[0].message.content

    if not output_text:
        raise RuntimeError(
            "Qwen returned an empty OCR response."
        )

    return output_text.strip()

# %% [markdown]
# ### Test one image

# %%
test_image_path = "images/8.jpg"  

ocr_text = run_ocr_one_image(
    test_image_path,
    prompt_text_2
)

print(ocr_text)
# Out:
# Vorwort.
#
# Das Jahr 1885 brachte die erste Fortsetzung des K. Ruprecht mit dem zweiten
# Bande von dessen Regierung, dem fünften der ganzen Reihe. Im Jahr 1887 wurde
# die dritte Abtheilung der Zeit K. Sigmund's ausgegeben, der neunte Band der Reichs-
# tagsakten. Jetzt nach einem Jahre können wir bereits den sechsten Band mittheilen,
# welcher zugleich der dritte und Schlußband K. Ruprecht's ist. Hiemit schließt sich die
# Lücke, welche in der Regierung dieses Königs noch auszufüllen war, und die sämmt-
# lichen bisher erschienenen neun Bände bilden eine ununterbrochene Kette. Mit dem
# zehnten Bande, dessen Ausgabe das nächste sein wird, soll dann auch die Periode K.
# Sigmund's zu ihrem Ende kommen.
#
# I. Bearbeitung des vorliegenden Bandes.
#
# Die Leitung des Unternehmens ruht wie bisher in der Hand H. v. Sybel's. Von
# früheren Mitarbeitern des Bandes, welche bei den Vorarbeiten überhaupt sowie ins-
# besondere bei der Anfertigung von Regesten Auszügen und Abschriften thätig waren,
# sind zu nennen Kerler, Menzel, Schäffler, Friedensburg. Gelegentliche
# Unterstützung gewährte uns die Güte der Herren Dr. Liebermann für London,
# Dr. Mau für Rom, Prof. Schöne für Paris, Dr. G. Wolfram für Straßburg i. E.,
# kleinerer Auskunftsertheilungen, die uns von Seiten mancher Archiv- und Bibliotheks-
# Beamten wurden, nicht zu gedenken. Die Hauptsache aber haben wir drei gethan,
# nemlich Prof. Ernst Bernheim in Greifswald, Dr. Ludwig Quidde zu Königs-
# berg i. Pr., und ich. Es verhält sich mit unserer gleichen Berechtigung zur Nennung
# als Herausgeber dieses sechsten Bandes und mit unserer gleichen Verantwortlichkeit als
# untrennbarer Genossen ganz wie beim fünften Bande, auf dessen Vorwort S. I ich in
# dieser Hinsicht verweise. Die Korrektur des vorliegenden Bandes hat Quidde besorgt,
# unter wechselnder Mitwirkung von Bernheim und der jetzigen ständigen Mitarbeiter
# in Frankfurt a. M. Dr. Schellhaß und Dr. Heuer, sowie des cand. phil. Ruttke
# in Königsberg i. Pr. Das Chronologische Verzeichniß der Urkunden und Akten und
# das Alphabetische Register der Orts- und Personen-Namen hat Schellhaß bearbeitet.
# Der Verlagshandlung von Friedrich Andreas Perthes in Gotha haben wir
# neben der Sicherheit des Druckverfahrens auch ganz insbesondere die ungemeine Rasch-
# heit zu verdanken, mit welcher der vorliegende ziemlich umfangreiche Band auf den
# letzten von 1887 gefolgt ist. Sehr zu bedauern haben wir den Weggang des Herrn
# Dr. H. Grotefend vom Stadtarchiv in Frankfurt a. M., indem derselbe nicht bloß
# als Vorstand seiner für uns so wichtigen Anstalt sondern auch als allezeit bereiter Be-
# rather und Helfer in wissenschaftlichen Dingen sich die größten Verdienste um unsere
# Deutsche Reichstags-Akten VI.
# I

# %%
# test one page wer cer
import re
import requests
from jiwer import wer, cer

page = 8

def normalize_text(text):
    text = text.lower()
    text = text.strip()
    text = re.sub(r"\s+", " ", text)
    return text


gold_url = f"https://nlp.fi.muni.cz/projekty/ahisto/ocr-output/494/{page}.txt"
gold_text = requests.get(gold_url).text

gold_norm = normalize_text(gold_text)
pred_norm = normalize_text(ocr_text)

wer_score = wer(gold_norm, pred_norm)
cer_score = cer(gold_norm, pred_norm)


print(f"=== Single Page Evaluation (Page {page}) ===")
print(f"WER: {wer_score:.4f} ({wer_score * 100:.2f}%)")
print(f"CER: {cer_score:.4f} ({cer_score * 100:.2f}%)")
# Out:
# === Single Page Evaluation (Page 8) ===
# WER: 0.0199 (1.99%)
# CER: 0.0033 (0.33%)

# %% [markdown]
# ### Try in three images

# %%
import os

output_dir = "outputs/prompt_result"
os.makedirs(output_dir, exist_ok=True)

# %%
for p in pages:
    print(f"\n==============================")
    print(f"Page {p}")
    print(f"==============================")

    image_path = f"images/{p}.jpg"
    output_path = os.path.join(output_dir, f"page_{p}.txt")

    output_text = run_ocr_one_image(image_path, prompt_text_2)

    print(output_text)

    with open(output_path, "w", encoding="utf-8") as f:
        f.write(output_text)

    print(f"Saved: {output_path}")
# Out:
# ==============================
# Page 8
# ==============================
# Vorwort.
#
# Das Jahr 1885 brachte die erste Fortsetzung des K. Ruprecht mit dem zweiten
# Bande von dessen Regierung, dem fünften der ganzen Reihe. Im Jahr 1887 wurde
# die dritte Abtheilung der Zeit K. Sigmund's ausgegeben, der neunte Band der Reichs-
# tagsakten. Jetzt nach einem Jahre können wir bereits den sechsten Band mittheilen,
# welcher zugleich der dritte und Schlußband K. Ruprecht's ist. Hiemit schließt sich die
# Lücke, welche in der Regierung dieses Königs noch auszufüllen war, und die sämmt-
# lichen bisher erschienenen neun Bände bilden eine ununterbrochene Kette. Mit dem
# zehnten Bande, dessen Ausgabe das nächste sein wird, soll dann auch die Periode K.
# Sigmund's zu ihrem Ende kommen.
#
# I. Bearbeitung des vorliegenden Bandes.
#
# Die Leitung des Unternehmens ruht wie bisher in der Hand H. v. Sybel's. Von
# früheren Mitarbeitern des Bandes, welche bei den Vorarbeiten überhaupt sowie ins-
# besondere bei der Anfertigung von Regesten Auszügen und Abschriften thätig waren,
# sind zu nennen Kerler, Menzel, Schäffler, Friedensburg. Gelegentliche
# Unterstützung gewährte uns die Güte der Herren Dr. Liebermann für London,
# Dr. Mau für Rom, Prof. Schöne für Paris, Dr. G. Wolfram für Straßburg i. E.,
# kleinerer Auskunftsertheilungen, die uns von Seiten mancher Archiv- und Bibliotheks-
# Beamten wurden, nicht zu gedenken. Die Hauptsache aber haben wir drei gethan,
# nemlich Prof. Ernst Bernheim in Greifswald, Dr. Ludwig Quidde zu Königs-
# berg i. Pr., und ich. Es verhält sich mit unserer gleichen Berechtigung zur Nennung
# als Herausgeber dieses sechsten Bandes und mit unserer gleichen Verantwortlichkeit als
# untrennbarer Genossen ganz wie beim fünften Bande, auf dessen Vorwort S. I ich in
# dieser Hinsicht verweise. Die Korrektur des vorliegenden Bandes hat Quidde besorgt,
# unter wechselnder Mitwirkung von Bernheim und der jetzigen ständigen Mitarbeiter
# in Frankfurt a. M. Dr. Schellhaß und Dr. Heuer, sowie des cand. phil. Ruttke
# in Königsberg i. Pr. Das Chronologische Verzeichniß der Urkunden und Akten und
# das Alphabetische Register der Orts- und Personen-Namen hat Schellhaß bearbeitet.
# Der Verlagshandlung von Friedrich Andreas Perthes in Gotha haben wir
# neben der Sicherheit des Druckverfahrens auch ganz insbesondere die ungemeine Rasch-
# heit zu verdanken, mit welcher der vorliegende ziemlich umfangreiche Band auf den
# letzten von 1887 gefolgt ist. Sehr zu bedauern haben wir den Weggang des Herrn
# Dr. H. Grotefend vom Stadtarchiv in Frankfurt a. M., indem derselbe nicht bloß
# als Vorstand seiner für uns so wichtigen Anstalt sondern auch als allezeit bereiter Be-
# rather und Helfer in wissenschaftlichen Dingen sich die größten Verdienste um unsere
# Deutsche Reichstags-Akten VI.
# I
# Saved: outputs/prompt_result/page_8.txt
#
# ==============================
# Page 9
# ==============================
# II
# Vorwort.
# Unternehmung erworben hat und wie für das städtische Institut so auch für uns schwer
# zu ersetzen ist.
# Noch immer steht das eigentliche Aktenmaterial zurück hinter der Gesammtzahl
# von Urkunden und Briefen, hat sogar gegenüber vom fünften Band wieder abgenommen.
# Es finden sich Protokolle oder Protokollartiges und Abschiede oder Beschlüsse, Venetia-
# nische Provenienzen mitgerechnet, 25 an der Zahl (nr. 5. 6. 13. 14. 15. 27. 89. 110.
# 126. 145-147. 163. 171. 234. 307. 320. 325. 336. 337. 368. 397. 399. 400. 401), Denk-
# schriften Gutachten Meinungsäußerungen u. dgl. 9 (11. 12. 41. 268. 298. 299. 301. 309.
# 370), Reden in weltlichen und kirchlichen Versammlungen 4 (269. 296. 300. 311), Ge-
# sandtschaftsanweisungen 16 (3. 7. 19. 25. 26. 30. 34. 78. 109. 114. 175. 195. 266. 282.
# 324. 331), Gesandtschaftswerbungen 3 (24. 280. 283), Gesandtschaftsschreiben nach
# Haus oder anderswohin 13 (4. 16. 17. 40. 67. 79. 100. 116. 125. 141-143. 187), Be-
# glaubigungen Ernennungen und Vollmachten für Gesandte oder sonstige Beauftragte 22
# (149. 162. 182. 249. 251. 253. 265. 275. 288. 292-294. 302. 306. 312. 318. 319. 365.
# 395. 416. 417. 427), Geleit Geleitsbrief und Geleitsgegenbrief 6 (68. 244. 247. 248.
# 254. 255), Tagesausschreiben und Einladungen zu Tagen 25 (1. 2. 32. 36. 38. 63.
# 71-73. 76. 112. 154. 164. 165. 237. 267. 333. 344. 364. 372. 377. 379. 398. 420. 430),
# Präsenz- und andere Listen 2 (9. 138), Bünde mit Beitritten und Aufnahmen 25
# (43-48. 80. 103-106. 176-179. 183. 184. 186. 188-190. 403-405. 408), Landfrieden Land-
# friedensbestätigungen Landfriedenszusätze 5 (270-274), Münzgesetze und -Verträge und
# -Ordnungen und -Abschiede und -Gutachten 9 (97. 98. 192. 342. 346. 348. 352. 354.
# 380), Münzproben 2 (203. 332), Kosten und städtische Vorbereitungen zum Reichstag
# 23 (10. 42. 69. 102. 135. 136. 235. 236. 259-264. 361-363. 388-390. 407. 409. 410),
# königliche Kammereinnahmen 1 (nr. 435), Korrespondenzen überhaupt in bedeutender
# Zahl, Beschwerden, Repliken, Urtheile, Schiedssprüche, Vereinbarungen, Appellationen,
# Versprechungen, Verträge, Befehle, Eidesformeln, Verbürgungen, Urkunden, Notizen,
# u. s. w.
# Die Zahl der Stücknummern ist 435, ungerechnet die zahlreichen urkundlichen
# Mittheilungen in den Einleitungen und Noten. Unter jenen fortlaufend numerirten
# Stücken waren bisher, wenn ich recht zähle, 284 völlig unbekannt, 67 waren ungedruckt
# und nur durch Regest oder Auszug oder Erwähnung oder Benützung bekannt, 16 theil-
# weise oder zum größten Theil oder fast ganz oder in Übersetzung bereits gedruckt, 67
# vollständig gedruckt und hier aus den Handschriften neu wiedergegeben, und endlich 1,
# das handschriftlich nicht vorlag, ist aus dem ersten früheren Drucke wiederholt. Also
# im ganzen sind 351 Nummern ungedruckt gewesen, 29 mehr als im fünften Bande, und
# 84 ganz oder theilweise gedruckt, also 93 weniger als im genannten Bande, an völlig
# unbekannten Nummern aber hat der vorliegende 51 mehr als jener, obschon er im ganzen
# 64 Nummern weniger aufweist als der fünfte. Bei dieser Aufzählung ist kein Unter-
# schied gemacht zwischen solchen Stücken, deren vollen Text wir mittheilen, und denje-
# nigen, die wir bloß als Regest oder Auszug oder theilweise geben.
# Für Vieles, was hier mitgetheilt ist, gelten auch wieder wie beim vierten und
# fünften Bande die Nachrichten, welche über die Quellen zum vierten Band in dessen
# Vorwort S. III-XXII niedergelegt sind, und wir haben einfach auf diese frühere Stelle
# zu verweisen.
# II. Einige Ergebnisse daraus.
# Ich beschränke mich bei der Frage von den Ergebnissen dieses Bandes auf einiges
# wenige, indem ich hauptsächlich im Auge behalte, wo durch das Suchen in Archiven
# und Bibliotheken der Umfang des Materials erweitert wurde.
# Saved: outputs/prompt_result/page_9.txt
#
# ==============================
# Page 38
# ==============================
# E. Klageartikel des Königs und des Mainzer Erzbischofs gegen einander nr. 11-12. 27
# dingen als wir in einunge 1 mit im waren und verschriben was in welcher maß man [1406
# alle sache von unser" beider dienere und der unsern wegen ußtragen solte. Jan. 8
# [7] Item 2 daz wir unsere clostere unser phaffheit geistlich und werntlich und die oder 9]
# unsern durch unsers herren des koniges land geschediget werden und genommen wirdet,
# 5 und ist siner amptlude keiner der das were, sunder unser fiende werden an sinen furten
# und faren mit der name ußergelaßen. und wann die unsern unser fiende widderumb
# stüchen durch sine lande, so ziehen sine amptlude und dienere zü und fahen stechen
# und handeln die unsern ubel, als den unsern daz nū kurzlich von den sinen ge-
# scheen ist.
# 10 [8] Item nimpt unsers herren des konniges faut zü Heydelberg in unserm gerichte
# zu Benßheim dem probest von Lorsche unserm priestern und mannen zü Bensheim ire
# golte b gotislehene und manplehen mit gewalt, und mogen ires rechtlichen alten beseßs,
# den sie lenger dann imands gedenken mag gewerlichen herbracht han, nit gnißen, als
# doch in geistlichen und werntlichen rechten gewonlich und recht ist.
# 15 [9] Item han wir veranlaßt und gestalt c sachen mit unserm herren dem konige,
# als umb daz gerichte zü Hentschwesheim d, daz holz den Muckenstorm, und die welde
# zu Rynberg 3; mag uns des kein ußtrag werden, sunder zu unser und unser gerichte
# swechung e und schaden besetzt er mit sinen burgern zü Heydelberg ein gerichte zü
# Nüwenheim die dann mit den von Heidelberg und andern den sinen binnen solichem
# 20 anlaße und stallunge die unsern mit undergangen pandungen und tegelichem betrange
# dicke und viel betrangen und verkürzen und itzunt die welde ußgeben und verhauwen
# han, also daz unser armen lude eins teils zu Hentschwesheim darumb daz dorf räumen
# mußen.
# [10] Item haben unsers herren des koniges amptlude, uns und unserm stift zü
# 25 schaden und nach der zit als unser sloß Bingen verbrant was, den luden uf der straßen
# mit gewalt geweret unsern markt zu Bingen zü suchen und darauf zu füren; und wart
# doch darnach beredt daz das abesin solte, und doch sieder geweret ist; soliche und
# andere unsere merkte wir von dem heiligen riche und in friedelicher gewere herbracht
# han und unser herre der konig als ein Romscher konnig und von briewe wegen die
# 30 wir von im han uns dabi moglich hanthaben schuren und schirmen solte.
# [11] Item als unser herre der konig moglich alle straßen schuren und schirmen
# solte, haben sine amptlude und die sinen of der straße gein Binge zü und of der straße
# zuschen Olmen und Mencze beide unser armenlude und andere mit slagen fahen won-
# den und nemen widder hinder sich geslagen und in geweret früchte nach irer noitdorft
# 35 zü füren als doch von alter herkommen ist.
# [12] Item 4 hait unser herre der konnig von eins lantfrieden 5 wegen f, in dem
# wir nit sin als 6 wir oder die unsern des nit zu schaffen han, zolle of straßen und in
# steten laßen machen und gesatzt, da die unsern gezollet und gephendet werden und
# schaden nemen; und meinen, diweile wir und die unsern des lantfrieden nit gnißen, daz
# 40 wir und die unsern des unmogelichen engelten h 6.
# a) A unserer mit Durchstreichung des zweiten r, B unser. b) B gulio. c) B veranlaßte und gestalte. d) A Hent-
# schwesheim, B Hentschwesheim. e) A scheint urspr. sweche, dann gebessert in swechug; daher aussehend
# wie swechrig; B swechit. f) add. B. g) om. AB. h) A korr. aus engüiten, B einfach engelten.
# 1 S. Bd. 5 nr. 373, besonders art. 1a-1d.
# 45 2 Vgl. nr. 82 art. 5.
# 3 S. RTA. 3 nr. 201 art. 2. 3. 5 und RTA. 4
# nr. 208 art. 2. 3. 5. Wegen Handschuhsheim
# vgl. auch nr. 82 art. 1.
# 4 Vgl. nr. 14 art. 2 und nr. 12 art. 7.
# 5 In der Wetterau, Bd. 5 nr. 438.
# 6 Auch Straßburg wollte sich die Erhebung der
# Landfriedenszölle nicht gefallen lassen und nahm
# deshalb seinerseits Frankfurter Bürgern ungewöhn-
# 4*
# Saved: outputs/prompt_result/page_38.txt

# %% [markdown]
# ## Evaluation

# %%
def normalize_text(text):
    text = text.lower()
    text = text.strip()
    text = re.sub(r"\s+", " ", text)
    return text

# %%
results_exp1 = []

gold_base = "https://nlp.fi.muni.cz/projekty/ahisto/ocr-output/494/"

for p in pages:
    print(f"Evaluating page {p}...")

    gold_url = f"{gold_base}{p}.txt"
    gold_text = requests.get(gold_url).text

    pred_path = os.path.join(output_dir, f"page_{p}.txt")
    with open(pred_path, "r", encoding="utf-8") as f:
        pred_text = f.read()

    gold_norm = normalize_text(gold_text)
    pred_norm = normalize_text(pred_text)


    wer_score = wer(gold_norm, pred_norm)
    cer_score = cer(gold_norm, pred_norm)

    results_exp1.append({
        "page": p,
        "WER": wer_score,
        "CER": cer_score
    })
# Out:
# Evaluating page 8...
# Evaluating page 9...
# Evaluating page 38...

# %%
print("=== Prompt Results: Qwen3.5-35B-A3B ===")
df_exp1 = pd.DataFrame(results_exp1)
df_exp1
# Out:
# === Prompt Results: Qwen3.5-35B-A3B ===
#    page       WER       CER
# 0     8  0.019851  0.003348
# 1     9  0.023132  0.004056
# 2    38  0.123145  0.034965

# %%
mean_wer = df_exp1["WER"].mean()
mean_cer = df_exp1["CER"].mean()

print("=== Prompt Results ===")
print(f"Mean WER: {mean_wer:.4f}")
print(f"Mean CER: {mean_cer:.4f}")
# Out:
# === Prompt Results ===
# Mean WER: 0.0554
# Mean CER: 0.0141

# %%
import os

output_dir_result_1 = "outputs/prompt_result_img"
os.makedirs(output_dir_result_1, exist_ok=True)

# %%
import os
import matplotlib.pyplot as plt

mean_wer = df_exp1["WER"].mean()
mean_cer = df_exp1["CER"].mean()

save_path = os.path.join(output_dir_result_1, "experiment_1_results.png")

fig, ax = plt.subplots(figsize=(10, len(df_exp1) * 0.45 + 2))
ax.axis("off")


fig.suptitle("Prompt Results - Qwen3.5-35B-A3B", fontsize=16, y=0.98)

summary_text = f"Mean WER: {mean_wer}    |    Mean CER: {mean_cer}"
fig.text(0.5, 0.90, summary_text, ha="center", va="center", fontsize=12)

# Table
table = ax.table(
    cellText=df_exp1.values,
    colLabels=df_exp1.columns,
    cellLoc="center",
    colLoc="center",
    loc="center"
)

table.auto_set_font_size(False)
table.set_fontsize(8)
table.scale(1, 1.3)

ax.set_position([0.1, 0.08, 0.8, 0.78])

fig.savefig(save_path, dpi=300, bbox_inches="tight", facecolor="white")
plt.show()
plt.close(fig)

print("Saved:", save_path)
# Out:
# Saved: outputs/prompt_result_img/experiment_1_results.png

# %%
import numpy as np
x = np.arange(len(df_exp1))
width = 0.35

wer_pct = df_exp1["WER"] * 100
cer_pct = df_exp1["CER"] * 100

plt.figure(figsize=(10,5))

bars1 = plt.bar(x - width/2, wer_pct, width, label="WER")
bars2 = plt.bar(x + width/2, cer_pct, width, label="CER")

for bar in bars1:
    plt.text(
        bar.get_x() + bar.get_width()/2,
        bar.get_height(),
        f"{bar.get_height():.1f}%",
        ha="center",
        va="bottom",
        fontsize=8
    )

for bar in bars2:
    plt.text(
        bar.get_x() + bar.get_width()/2,
        bar.get_height(),
        f"{bar.get_height():.1f}%",
        ha="center",
        va="bottom",
        fontsize=8
    )

plt.xticks(x, df_exp1["page"])
plt.xlabel("Page")
plt.ylabel("Error Rate (%)")
plt.title("Prompt-2 Results (Qwen3.5-35B-A3B): WER and CER by Page")

plt.legend()
plt.grid(axis="y", alpha=0.3)

plt.ylim(0, 15)
plt.yticks(np.arange(0, 16, 2))

os.makedirs(output_dir_result_1, exist_ok=True)

plt.savefig(
    os.path.join(
        output_dir_result_1,
        "experiment_1_wer_cer_by_page.png"
    ),
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# ## Prompt Comparison

# %%
import os

page = 9

prompt_dict = {
    "Prompt 1": prompt_text_0,
    "Prompt 2": prompt_text_1,
    "Prompt 3": prompt_text_2,
}

base_output_dir = "outputs/prompt_comparison"
os.makedirs(base_output_dir, exist_ok=True)

image_path = f"images/{page}.jpg"

for prompt_name, prompt_text in prompt_dict.items():

    folder_name = prompt_name.lower().replace(" ", "_")
    output_dir = os.path.join(base_output_dir, folder_name)
    os.makedirs(output_dir, exist_ok=True)

    print(f"Running {prompt_name} on page {page}...")

    output_text = run_ocr_one_image(
        image_path,
        prompt_text
    )

    output_path = os.path.join(
        output_dir,
        f"page_{page}.txt"
    )

    with open(output_path, "w", encoding="utf-8") as f:
        f.write(output_text)

    print(f"Saved: {output_path}")
# Out:
# Running Prompt 1 on page 8...
# Saved: outputs/prompt_comparison/prompt_1/page_8.txt
# Running Prompt 2 on page 8...
# Saved: outputs/prompt_comparison/prompt_2/page_8.txt
# Running Prompt 3 on page 8...
# Saved: outputs/prompt_comparison/prompt_3/page_8.txt

# %%
import re
import requests
import pandas as pd
from jiwer import wer, cer


def normalize_text(text):
    text = text.lower()
    text = text.strip()
    text = re.sub(r"\s+", " ", text)
    return text


gold_url = (
    f"https://nlp.fi.muni.cz/"
    f"projekty/ahisto/ocr-output/494/{page}.txt"
)

response = requests.get(gold_url)
response.raise_for_status()

gold_text = response.text
gold_norm = normalize_text(gold_text)

comparison_results = []

for prompt_name in prompt_dict:

    folder_name = prompt_name.lower().replace(" ", "_")

    pred_path = os.path.join(
        base_output_dir,
        folder_name,
        f"page_{page}.txt"
    )

    with open(pred_path, "r", encoding="utf-8") as f:
        pred_text = f.read()


    pred_norm = normalize_text(pred_text)

    wer_score = wer(gold_norm, pred_norm)
    cer_score = cer(gold_norm, pred_norm)

    comparison_results.append({
        "Prompt": prompt_name,
        "WER": wer_score,
        "CER": cer_score,
        "WER (%)": wer_score * 100,
        "CER (%)": cer_score * 100
    })

comparison_df = pd.DataFrame(comparison_results)

comparison_df
# Out:
#      Prompt       WER       CER   WER (%)   CER (%)
# 0  Prompt 1  0.054591  0.008185  5.459057  0.818452
# 1  Prompt 2  0.052109  0.007812  5.210918  0.781250
# 2  Prompt 3  0.019851  0.003348  1.985112  0.334821

# %% [markdown]
# ## Plot Comparison

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(len(comparison_df))
width = 0.35

plt.figure(figsize=(8, 5))

wer_bars = plt.bar(
    x - width / 2,
    comparison_df["WER (%)"],
    width,
    label="WER"
)

cer_bars = plt.bar(
    x + width / 2,
    comparison_df["CER (%)"],
    width,
    label="CER"
)

for bar in wer_bars:
    plt.text(
        bar.get_x() + bar.get_width() / 2,
        bar.get_height(),
        f"{bar.get_height():.2f}%",
        ha="center",
        va="bottom"
    )

for bar in cer_bars:
    plt.text(
        bar.get_x() + bar.get_width() / 2,
        bar.get_height(),
        f"{bar.get_height():.2f}%",
        ha="center",
        va="bottom"
    )

plt.xticks(x, comparison_df["Prompt"])
plt.xlabel("Prompt")
plt.ylabel("Error Rate (%)")
plt.title(f"Prompt Comparison — Page {page}")
plt.legend()
plt.tight_layout()

save_path = os.path.join(
    base_output_dir,
    f"page_{page}_prompt_comparison.png"
)

plt.savefig(
    save_path,
    dpi=300,
    bbox_inches="tight"
)

plt.show()

print("Saved:", save_path)
# Out:
# Saved: outputs/prompt_comparison/page_8_prompt_comparison.png
